# %% [markdown]
# <a href="https://colab.research.google.com/github/clarkeri88/test/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.interactiveshell import SeparateUnicode
from os import sep
 ## Hashtags are notes

 #the following are all examples of assinging values to variables

interest = 3 #Interest Rate (absolute value)
principal= 3000
n = 1 # 1 year interest

 #calculating expression final using the variables as inputs, and printing the result
final = principal*(1+interest/100)**n

print(final)
#above is an example of a function: print function
#Note: * is multiplication, ** is raised to the power of


##Notes on Functions :
  #Functions must take in paramters ()
  #for function print, inside the parameter: print(Here) is object to be displayed

  #parameter end or "\n" controls what happens at the end of a displayed message :(this doesnt appear on screen)

    ## print ("interest rate:",principal, end="---" )
    ## print ("Number of years:", n, sep=" ")
    #3will print: Interest rate: 3---Number of years: 1

  #can print multiple objects like this: print (interest, principal) will print = 3 3000

  #If you print something in quotes "something" it will print the text in the quotes

  #sep= in the print parameter seperates two objects in parameter
      # print ("interest rate:"",principal, sep=" => ") will print : Interest rate:=>3
print(interest,principal)
print(final)


print("interest rate:", interest)
print("Number of years:" , n)

##Dynamic string: is a string in which its value is dynamic(can change over time)

  #Method 1: Method format: a string method(only string method in this course), it assigns dynamic values to placeholders inside the string.
  # Defined as : "....{}..{}....".format(a,b)
  #those brackets{} are the placeholders for dynamic variables
  # where a,b is above : in there put the object whose value is to be assigned to the placeholders in the brackets

print("Interest Rate: {}; Number of years: {}".format(interest,n))

  #Method 2:
  #  f"....{a}....{b}"

print(f"Interest rate: {interest}; Number of years: {n}") #best overall print method

##Function Input : allows for user input and prompts user for input

interest = input("Enter an interest value (%)")  # inside parameters of input function is what the user sees
print ("interest given by user", interest)

interest= float(input("Enter an interest value (%)")) ## this will change type of input to float, you can also replace float with Int to get integer

#function type:
    #type(interest)
#ex.
interest = int(input("Enter an interest value (%)"))  # inside parameters of input function is what the user sees
print ("interest given by user", interest)
type(interest)
# Out:
# 3090.0
# 3 3000
# 3090.0
# interest rate: 3
# Number of years: 1
# Interest Rate: 3; Number of years: 1
# Interest rate: 3; Number of years: 1
# Enter an interest value (%)5t0
# interest given by user 5t0
# Enter an interest value (%)50
# Enter an interest value (%)50
# interest given by user 50
# int

# %%
##Conditionals : to perform decision making in the program : key word "if"

#if condition:

#ex.
email= "URGENT!!! Click on the link: www.phis.org for a reward"
has_urgent= "URGENT"

if has_urgent in email:
  print("Phising!")
# Out:
# Phising!
